# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Importing dataset

# %%
df=pd.read_csv("https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/World%20Happiness/happiness_score_dataset.csv")
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.tail(10)
# Out:
#           Country                           Region  Happiness Rank  \
# 148          Chad               Sub-Saharan Africa             149
# 149        Guinea               Sub-Saharan Africa             150
# 150   Ivory Coast               Sub-Saharan Africa             151
# 151  Burkina Faso               Sub-Saharan Africa             152
# 152   Afghanistan                    Southern Asia             153
# 153        Rwanda               Sub-Saharan Africa             154
# 154         Benin               Sub-Saharan Africa             155
# 155         Syria  Middle East and Northern Africa             156
# 156       Burundi               Sub-Saharan Africa             157
# 157          Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 148            3.667         0.03830                   0.34193  0.76062
# 149            3.656         0.03590                   0.17417  0.46475
# ...

# %%
df.shape
# Out:
# (158, 12)

# %% [markdown]
# The dataset contains 158 rows and 12 columns

# %%
print("The dimension of the dataset",df.shape)
print(f"\nThe columns headers in the dataset:{df.columns}")
# Out:
# The dimension of the dataset (158, 12)
#
# The columns headers in the dataset:Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# The dataset contains 2 string columns and 10 numerical columns

# %% [markdown]
# # Checking for NAN,np.nan,None,null value

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# Find that there is no null value in the data and there are 2 object columns , 9 float and 1 integer column and memory usage is 14.9 kb

# %% [markdown]
# From here we can find that happiness score is label which is contains datatype in float so it will be termed as Regression problem so to predict the happiness score using the regression model

# %% [markdown]
# Also require to convert country and region from object to numerical data type using label encoder before doing any EDA ,preprocessing

# %%
#Separating numerical and categorical column

categorical_col=[]

for i in df.dtypes.index:
    if df.dtypes[i]=="object":
        categorical_col.append(i)
print("Categorical Columns :",categorical_col)
print("\n")        
        
num_col=[]

for i in df.dtypes.index:
    if df.dtypes[i]!="object":
        num_col.append(i)
print("Numerical Columns :",num_col)
print("\n")
# Out:
# Categorical Columns : ['Country', 'Region']
#
#
# Numerical Columns : ['Happiness Rank', 'Happiness Score', 'Standard Error', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']

# %% [markdown]
# Here  we categories data in the form of dtypes to convert into numerical datatype (int,float) or drop these column as not giving any relationship with happiness_score, country and region are also defined according with other independent variable like economy,family freedom etc

# %%
#Checking the value count of each columns

for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# Switzerland    1
# Bangladesh     1
# Greece         1
# Lebanon        1
# Hungary        1
#               ..
# Kazakhstan     1
# Slovenia       1
# Lithuania      1
# Nicaragua      1
# Togo           1
# Name: Country, Length: 158, dtype: int64
#
#
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64
#
#
# 82     2
# 1      1
# 110    1
# 103    1
# 104    1
#       ..
# 54     1
# 55     1
# 56     1
# 57     1
# 158    1
# Name: Happiness Rank, Length: 157, dtype: int64
#
#
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# ...

# %% [markdown]
# Where we can find every column unique value is almost equal to count of columns so the data is equally distributed in the dataset with least biasness and high variance for analysis

# %%
df["Happiness Score"].unique()
# Out:
# array([7.587, 7.561, 7.527, 7.522, 7.427, 7.406, 7.378, 7.364, 7.286,
#        7.284, 7.278, 7.226, 7.2  , 7.187, 7.119, 6.983, 6.946, 6.94 ,
#        6.937, 6.901, 6.867, 6.853, 6.81 , 6.798, 6.786, 6.75 , 6.67 ,
#        6.611, 6.575, 6.574, 6.505, 6.485, 6.477, 6.455, 6.411, 6.329,
#        6.302, 6.298, 6.295, 6.269, 6.168, 6.13 , 6.123, 6.003, 5.995,
#        5.987, 5.984, 5.975, 5.96 , 5.948, 5.89 , 5.889, 5.878, 5.855,
#        5.848, 5.833, 5.828, 5.824, 5.813, 5.791, 5.77 , 5.759, 5.754,
#        5.716, 5.709, 5.695, 5.689, 5.605, 5.589, 5.548, 5.477, 5.474,
#        5.429, 5.399, 5.36 , 5.332, 5.286, 5.268, 5.253, 5.212, 5.194,
#        5.192, 5.14 , 5.129, 5.124, 5.123, 5.102, 5.098, 5.073, 5.057,
#        5.013, 5.007, 4.971, 4.959, 4.949, 4.898, 4.885, 4.876, 4.874,
#        4.867, 4.857, 4.839, 4.8  , 4.788, 4.786, 4.739, 4.715, 4.694,
#        4.686, 4.681, 4.677, 4.642, 4.633, 4.61 , 4.571, 4.565, 4.55 ,
# ...

# %%
df["Happiness Score"].nunique()
# Out:
# 157

# %%
df.nunique().to_frame("No. of unique value")
# Out:
#                                No. of unique value
# Country                                        158
# Region                                          10
# Happiness Rank                                 157
# Happiness Score                                157
# Standard Error                                 153
# Economy (GDP per Capita)                       158
# Family                                         158
# Health (Life Expectancy)                       157
# Freedom                                        158
# Trust (Government Corruption)                  157
# Generosity                                     158
# Dystopia Residual                              158

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
from sklearn.preprocessing import LabelEncoder
LE= LabelEncoder()

col_to_encode=["Country","Region"]


for col in col_to_encode:
    df[col] =LE.fit_transform(df[col])
    
df
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        135       9               1            7.587         0.03411
# 1         58       9               2            7.561         0.04884
# 2         37       9               3            7.527         0.03328
# 3        105       9               4            7.522         0.03880
# 4         24       5               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 153      118       8             154            3.465         0.03464
# 154       13       8             155            3.340         0.03656
# 155      136       4             156            3.006         0.05015
# 156       21       8             157            2.905         0.08658
# 157      141       8             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    int32
#  1   Region                         158 non-null    int32
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df.nunique().to_frame("No. of unique value")
# Out:
#                                No. of unique value
# Country                                        158
# Region                                          10
# Happiness Rank                                 157
# Happiness Score                                157
# Standard Error                                 153
# Economy (GDP per Capita)                       158
# Family                                         158
# Health (Life Expectancy)                       157
# Freedom                                        158
# Trust (Government Corruption)                  157
# Generosity                                     158
# Dystopia Residual                              158

# %% [markdown]
# Here it show that only the string data type changes to int for both country and region and value counts remain the same by using label encoder

# %% [markdown]
# # Description of Dataset

# %%
df.describe()
# Out:
#           Country      Region  Happiness Rank  Happiness Score  \
# count  158.000000  158.000000      158.000000       158.000000
# mean    78.500000    5.120253       79.493671         5.375734
# std     45.754781    2.993321       45.754363         1.145010
# min      0.000000    0.000000        1.000000         2.839000
# 25%     39.250000    3.000000       40.250000         4.526000
# 50%     78.500000    4.500000       79.500000         5.232500
# 75%    117.750000    8.000000      118.750000         6.243750
# max    157.000000    9.000000      158.000000         7.587000
#
#        Standard Error  Economy (GDP per Capita)      Family  \
# count      158.000000                158.000000  158.000000
# mean         0.047885                  0.846137    0.991046
# std          0.017146                  0.403121    0.272369
# min          0.018480                  0.000000    0.000000
# 25%          0.037268                  0.545808    0.856823
# ...

# %%
plt.figure(figsize=(22,10))
sns.heatmap(df.describe(),annot= True,fmt="0.2f",linewidth=0.2,linecolor="black",cmap="Spectral")
plt.xlabel("Figure",fontsize=14)
plt.ylabel("Features_Name",fontsize=14)
plt.title("Descriptive Grap",fontsize=20)
plt.show()

# %% [markdown]
# As observe that uniform distribution of data in table without any skewness present with outliers in few of the columns

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # Univariate Analysis

# %%
# Checking each columns with different plots to analysis

# %%
sns.countplot(x="Happiness Score",data=df)
print(df["Happiness Score"].value_counts())
# Out:
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# 2.839    1
# Name: Happiness Score, Length: 157, dtype: int64

# %%
sns.countplot(x="Region",data=df)
print(df["Region"].value_counts())
# Out:
# 8    40
# 1    29
# 3    22
# 9    21
# 4    20
# 6     9
# 7     7
# 2     6
# 5     2
# 0     2
# Name: Region, dtype: int64

# %% [markdown]
# # Checking the data Distribution

# %%
# Lets check how the data has been distributed in numerical column

plt.figure(figsize=(10,6),facecolor="white")
plotnum=1
for col in df:
    if plotnum<=12:
        ax=plt.subplot(2,6,plotnum)
        sns.distplot(df[col],color="m")
        plt.xlabel(col,fontsize = 12)
        plt.yticks(rotation = 0, fontsize = 10)
    plotnum+=1
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# This distribution plots show that dataset is uniform in each independent variable and label

# %% [markdown]
# As all the value_count is equal to the lenght of each column so not much to analyse using univariate plotting

# %% [markdown]
# # Bivariate Anlaysis

# %%
sns.lmplot(x="Happiness Score",y="Dystopia Residual",data=df,palette="colorblind")

# %%
sns.lmplot(x="Dystopia Residual",y="Happiness Score",data=df,palette="colorblind")

# %% [markdown]
# It show linear relationship of Happpiness Score with Dystopia Residual

# %% [markdown]
# lets check any relation of Target variable with independent variable and find any pattern using lm plot

# %%
plot_num=1
for col in df:
    if plot_num<=12:
        plt.figure(figsize=(10,2),facecolor="white")
        plt.subplot(6,6,plot_num)
        sns.lmplot(y='Happiness Score',x=col,data=df,palette="colorblind",scatter_kws={'alpha':0.3})
        plt.xlabel(col)
        plt.ylabel('Happiness Score')
    plot_num+=1
plt.show()

# %% [markdown]
# Happiness_score is show direct proportional with all the column except for country,region and inverse proportion to rank

# %%
#checking relationship using reg plot 


plt.figure(figsize=(20,25),facecolor="white")
p=1
for i in df:
    if p<=12:
        plt.subplot(5,4,p)
        sns.regplot(x=i,y="Happiness Score", data =df,color='r')
        plt.xlabel(i)
        plt.ylabel("Happiness Score")
    p+=1
plt.show()

# %%
#checking relationship using scatter plot

plt.figure(figsize=(20,25),facecolor="white")
p=1
for i in df:
    if p<=12:
        plt.subplot(5,4,p)
        sns.scatterplot(x=i,y="Happiness Score", data =df,color='r')
        plt.xlabel(i)
        plt.ylabel("Happiness Score")
    p+=1
plt.show()

# %% [markdown]
# Standard Error approx 0.04 has majorily covered all the Happiness Score 3-7 and all the other column except for country, region show linear relationship with label and feature so mainly it exists with all the columns

# %%
#Comparing Hapiness Score with Dystopia Residual and Region
plt.title("Comparing Hapiness Score with Dystopia Residual and Region")
sns.scatterplot(x="Dystopia Residual",y="Happiness Score",data=df,hue="Region",palette="bright")
plt.show()

# %%
#checking relationship using Violin Plot

plt.figure(figsize=(20,25),facecolor="white")
p=1
for i in df:
    if p<=12:
        plt.subplot(5,4,p)
        sns.violinplot(x=i,y="Happiness Score", data= df,)
        plt.xlabel(i)
        plt.ylabel("Happiness Score")
    p+=1
plt.show()

# %% [markdown]
# As the count and value count are equal not much insight can be found in bivariate analysis using violin plot

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(data =df)

# %% [markdown]
# # Checking for outliers

# %%
#lets check the outliers by plotting boxplot.


plt.figure(figsize=(10,6), facecolor="white")
plotnumber=1
for col in df:
    if plotnumber<=12:
        plt.subplot(2,6,plotnumber)
        sns.boxplot(df[col], palette = "Set2_r")
        plt.xlabel(col, fontsize = 5)
        plt.yticks(rotation=2, fontsize =2)
    plotnumber+=1
plt.show()

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# outliers are found in Standard Error, Family, Trust, Generosity, Dystopia Residual

# %%
from scipy.stats import zscore
up_score=df.iloc[:,:]
z=np.abs(zscore(up_score))
z
# Out:
#       Country    Region  Happiness Rank  Happiness Score  Standard Error  \
# 0    1.238770  1.300256        1.721000         1.937360        0.805926
# 1    0.449465  1.300256        1.699075         1.914581        0.055889
# 2    0.909893  1.300256        1.677149         1.884792        0.854487
# 3    0.581016  1.300256        1.655224         1.880411        0.531526
# 4    1.194920  0.040302        1.633299         1.797179        0.722845
# ..        ...       ...             ...              ...             ...
# 153  0.866043  0.965117        1.633576         1.674055        0.774917
# 154  1.436096  0.965117        1.655501         1.783571        0.662582
# 155  1.260695  0.375441        1.677427         2.076199        0.132534
# 156  1.260695  0.965117        1.699352         2.164688        2.263962
# 157  1.370321  0.965117        1.721277         2.222513        1.134182
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# ...

# %%
#threshold Z>3

np.where(z>3)
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64),
#  array([ 9,  4,  4,  4, 10,  6,  9, 11,  6], dtype=int64))

# %%
z.iloc[27,9]
# Out:
# 3.1646194851713774

# %%
df1= df[(z<3).all(axis=1)]
df1
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        135       9               1            7.587         0.03411
# 1         58       9               2            7.561         0.04884
# 2         37       9               3            7.527         0.03328
# 3        105       9               4            7.522         0.03880
# 4         24       5               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 150       66       8             151            3.655         0.05141
# 151       20       8             152            3.587         0.04324
# 152        0       7             153            3.575         0.03084
# 154       13       8             155            3.340         0.03656
# 156       21       8             157            2.905         0.08658
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
df1.shape
# Out:
# (149, 12)

# %%
print("old Data Frame ",df.shape[0])
print("New Data Frame ",df1.shape[0])
# Out:
# old Data Frame  158
# New Data Frame  149

# %%
print("Data Loss Percentage",((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# Data Loss Percentage 5.69620253164557

# %% [markdown]
# # Checking for Skewness

# %%
df1.skew()
# Out:
# Country                          0.048701
# Region                          -0.096985
# Happiness Rank                   0.003268
# Happiness Score                  0.169740
# Standard Error                   1.243048
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    1.272530
# Generosity                       0.654710
# Dystopia Residual               -0.021144
# dtype: float64

# %% [markdown]
# Standard Errorshow ,Trust (Government Corruption) these two variable show skewness more than +0.5 to -0.5 so removing skweness from these independent variable

# %% [markdown]
# # Removing skewness

# %%
df["Standard Error"]=np.cbrt(df["Standard Error"])
df["Trust (Government Corruption)"]=np.cbrt(df["Trust (Government Corruption)"])

# %%
plt.figure(figsize=(20,25),facecolor="red")
plotnumber=1

for column in df1:
    if plotnumber<=12:
        plt.subplot(6,4,plotnumber)
        sns.distplot(df1[column],color='green')
        plt.xlabel(column,fontsize=10)
    plotnumber+=1
plt.show()

# %% [markdown]
# # Correlation b/w target variable and independent variable

# %%
cor=df1.corr()

# %%
plt.figure(figsize=(26,14))
sns.heatmap(cor,annot=True,fmt="0.2f",linewidth = 0.2,linecolor="black", cmap="Spectral")
plt.xlabel("Figure",fontsize=14)
plt.ylabel("Features_Name", fontsize=14)
plt.title("Descriptive Graph", fontsize=20)
plt.show()

# %%
cor["Happiness Score"].sort_values(ascending=False)
# Out:
# Happiness Score                  1.000000
# Economy (GDP per Capita)         0.773577
# Health (Life Expectancy)         0.729191
# Family                           0.720868
# Freedom                          0.585066
# Dystopia Residual                0.528334
# Trust (Government Corruption)    0.477692
# Generosity                       0.250903
# Country                          0.120109
# Region                          -0.145850
# Standard Error                  -0.230252
# Happiness Rank                  -0.992921
# Name: Happiness Score, dtype: float64

# %% [markdown]
# # Visualizing the correlation between label and features using bar plot

# %%
#Visualizing the correlation between label and features using bar plot

plt.figure(figsize=(22,7))
cor['Happiness Score'].sort_values(ascending=False).drop(['Happiness Score']).plot(kind='bar',color='b')
plt.xlabel('Feature',fontsize=15)
plt.ylabel('Target',fontsize=15)
plt.title('Visualizing the correlation between label and features using bar plot')
plt.show()

# %% [markdown]
# As we can seen that As we can seen that Economy (GDP per Capita)  has +ve postive correlation with target label Happiness Score in high to low order as given and -ve correlation features are Happiness Rank and standard error  as these value  will tend to increase as these variable are inversely proportion to target variable

# %% [markdown]
# # Separating features and label

# %%
x= df1.drop(['Happiness Score','Country','Region'],axis=1)
y=df1['Happiness Score']

# %%
x
# Out:
#      Happiness Rank  Standard Error  Economy (GDP per Capita)   Family  \
# 0                 1         0.03411                   1.39651  1.34951
# 1                 2         0.04884                   1.30232  1.40223
# 2                 3         0.03328                   1.32548  1.36058
# 3                 4         0.03880                   1.45900  1.33095
# 4                 5         0.03553                   1.32629  1.32261
# ..              ...             ...                       ...      ...
# 150             151         0.05141                   0.46534  0.77115
# 151             152         0.04324                   0.25812  0.85188
# 152             153         0.03084                   0.31982  0.30285
# 154             155         0.03656                   0.28665  0.35386
# 156             157         0.08658                   0.01530  0.41587
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %% [markdown]
# # Feature Scaling using Standard Scalarization

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#      Happiness Rank  Standard Error  Economy (GDP per Capita)    Family  \
# 0         -1.713905       -0.866786                  1.381916  1.357879
# 1         -1.691535        0.185669                  1.138324  1.567882
# 2         -1.669166       -0.926089                  1.198220  1.401974
# 3         -1.646796       -0.531687                  1.543526  1.283947
# 4         -1.624427       -0.765327                  1.200315  1.250726
# ..              ...             ...                       ...       ...
# 144        1.641542        0.369294                 -1.026255 -0.945943
# 145        1.663911       -0.214450                 -1.562163 -0.624365
# 146        1.686281       -1.100427                 -1.402596 -2.811354
# 147        1.731020       -0.691734                 -1.488379 -2.608163
# 148        1.775759        2.882182                 -2.190139 -2.361154
#
#      Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# ...

# %% [markdown]
# # Checking Variance Inflation Factor(VIF)

# %%
# Finding variance inflation factor in each scaled column

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(x.values, i) for i in range(len(x.columns))]
vif["Features"]=x.columns

vif
# Out:
#    VIF values                       Features
# 0   82.821897                 Happiness Rank
# 1    1.206942                 Standard Error
# 2   13.208192       Economy (GDP per Capita)
# 3    6.356015                         Family
# 4    8.985079       Health (Life Expectancy)
# 5    3.500737                        Freedom
# 6    1.902647  Trust (Government Corruption)
# 7    1.965601                     Generosity
# 8   19.371438              Dystopia Residual

# %% [markdown]
#  As VIF value of Happiness rank Economy and dystopia is high compared to other Features but as the limited dataset cannot drop any feature for model building

# %% [markdown]
# # Modelling

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Creating Train Test Split

# %%
# finding the best Random State

maxAccu=0
maxRS=0

for i in range(0,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.20,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRs=i
        
print("Maximum r2 score is" , maxAccu,"on Random_state", maxRs)
# Out:
# Maximum r2 score is 0.9999999600120062 on Random_state 117

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.20,random_state=maxRS)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge

# %%
LR = LinearRegression()
LR.fit(x_train,y_train)
predLR=LR.predict(x_test)
pred_train=LR.predict(x_train)
print(LR)
print("R2_score:",r2_score(y_test,predLR))
print("R2 score on Training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,predLR))
print("Mean Squared Error:",mean_squared_error(y_test,predLR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,predLR)))
# Out:
# LinearRegression()
# R2_score: 0.9999999179724429
# R2 score on Training data: 99.9999941718157
# Mean Absolute Error: 0.0002603136167180331
# Mean Squared Error: 8.423360587069696e-08
# Root Mean Squared Error: 0.00029023026353345194

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=predLR,y=y_test,color="r")
plt.plot(predLR,predLR,color="b")
plt.xlabel("Actual",fontsize=14)
plt.ylabel("Predicted",fontsize=14)
plt.title("Linear Regression",fontsize=18)
plt.show()

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
predRFR=RFR.predict(x_test)
pred_train=RFR.predict(x_train)
print(RFR)
print("R2_score:",r2_score(y_test,predRFR))
print("R2 score on Training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,predRFR))
print("Mean Squared Error:",mean_squared_error(y_test,predRFR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,predRFR)))
# Out:
# RandomForestRegressor()
# R2_score: 0.9982823542602249
# R2 score on Training data: 99.90683630111741
# Mean Absolute Error: 0.03223766666666645
# Mean Squared Error: 0.0017638400966666422
# Root Mean Squared Error: 0.04199809634574694

# %%
knn=KNN()
knn.fit(x_train,y_train)
predknn=knn.predict(x_test)
predtrain=knn.predict(x_train)
print(knn)
print("R2_score:",r2_score(y_test,predknn))
print("R2 score on Training data:",r2_score(y_train,predtrain)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,predknn))
print("Mean Squared Error:",mean_squared_error(y_test,predknn))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,predknn)))
# Out:
# KNeighborsRegressor()
# R2_score: 0.9434523353095293
# R2 score on Training data: 94.99071032851371
# Mean Absolute Error: 0.1884333333333332
# Mean Squared Error: 0.058068457333333254
# Root Mean Squared Error: 0.2409739764649562

# %%
GBR= GradientBoostingRegressor()
GBR.fit(x_train,y_train)
predGBR=GBR.predict(x_test)
pred_train=GBR.predict(x_train)
print(GBR)
print("R2_score:",r2_score(y_test,predGBR))
print("R2 score on Training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,predGBR))
print("Mean Squared Error:",mean_squared_error(y_test,predGBR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,predGBR)))
# Out:
# GradientBoostingRegressor()
# R2_score: 0.998414981042178
# R2 score on Training data: 99.99989602589187
# Mean Absolute Error: 0.029173504424317247
# Mean Squared Error: 0.0016276464506291195
# Root Mean Squared Error: 0.04034410056785403

# %%
lasso=Lasso()
lasso.fit(x_train,y_train)
predlasso=lasso.predict(x_test)
predtrain=lasso.predict(x_train)
print(lasso)
print("R2_score:",r2_score(y_test,predlasso))
print("R2 score on Training data:",r2_score(y_train,predtrain)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,predlasso))
print("Mean Squared Error:",mean_squared_error(y_test,predlasso))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,predlasso)))
# Out:
# Lasso()
# R2_score: 0.22089340863942442
# R2 score on Training data: 22.379490805991185
# Mean Absolute Error: 0.769504620364265
# Mean Squared Error: 0.8000598805659309
# Root Mean Squared Error: 0.8944606646275346

# %%
rd=Ridge()
rd.fit(x_train,y_train)
predrd=rd.predict(x_test)
predtrain=rd.predict(x_train)
print(rd)
print("R2_score:",r2_score(y_test,predrd))
print("R2 score on Training data:",r2_score(y_train,predtrain)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,predrd))
print("Mean Squared Error:",mean_squared_error(y_test,predrd))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,predrd)))
# Out:
# Ridge()
# R2_score: 0.9997233055647935
# R2 score on Training data: 99.96681529924858
# Mean Absolute Error: 0.013543654644342951
# Mean Squared Error: 0.00028413585411718256
# Root Mean Squared Error: 0.016856329793795047

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
preddtr=dtr.predict(x_test)
predtrain=dtr.predict(x_train)
print(dtr)
print("R2_score:",r2_score(y_test,preddtr))
print("R2 score on Training data:",r2_score(y_train,predtrain)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,preddtr))
print("Mean Squared Error:",mean_squared_error(y_test,preddtr))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,preddtr)))
# Out:
# DecisionTreeRegressor()
# R2_score: 0.99376660749694
# R2 score on Training data: 100.0
# Mean Absolute Error: 0.056166666666666656
# Mean Squared Error: 0.006401033333333328
# Root Mean Squared Error: 0.08000645807266642

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(x_train,y_train)
predsvr=svr.predict(x_test)
predtrain=svr.predict(x_train)
print(svr)
print("R2_score:",r2_score(y_test,predsvr))
print("R2 score on Training data:",r2_score(y_train,predtrain)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,predsvr))
print("Mean Squared Error:",mean_squared_error(y_test,predsvr))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,predsvr)))
# Out:
# SVR()
# R2_score: 0.9793046123882246
# R2 score on Training data: 98.75336153058248
# Mean Absolute Error: 0.10881676749810427
# Mean Squared Error: 0.02125196927422692
# Root Mean Squared Error: 0.14578055176952417

# %%
#Checking accuracy for ExtraTreesRegressor
from sklearn.ensemble import ExtraTreesRegressor
ET=ExtraTreesRegressor()
ET.fit(x_train,y_train)
predET= ET.predict(x_test)
predtrain=ET.predict(x_train)
print(ET)
print("R2_score:",r2_score(y_test,predET))
print("R2 score on Training data:",r2_score(y_train,predtrain)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,predET))
print("Mean Squared Error:",mean_squared_error(y_test,predET))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,predET)))
# Out:
# ExtraTreesRegressor()
# R2_score: 0.9994063293751463
# R2 score on Training data: 100.0
# Mean Absolute Error: 0.019846000000000506
# Mean Squared Error: 0.0006096368000000487
# Root Mean Squared Error: 0.02469082420657619

# %%
#Checking accuracy for BaggingRegressor
from sklearn.ensemble import BaggingRegressor
BR=BaggingRegressor()
BR.fit(x_train,y_train)
predBR= BR.predict(x_test)
predtrain=BR.predict(x_train)
print(BR)
print("R2_score:",r2_score(y_test,predBR))
print("R2 score on Training data:",r2_score(y_train,predtrain)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,predBR))
print("Mean Squared Error:",mean_squared_error(y_test,predBR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,predBR)))
# Out:
# BaggingRegressor()
# R2_score: 0.9981400456052265
# R2 score on Training data: 99.89867355545495
# Mean Absolute Error: 0.03383333333333347
# Mean Squared Error: 0.001909976000000013
# Root Mean Squared Error: 0.04370327218870474

# %%
#Checking accuracy for AdaBoostRegressor
from sklearn.ensemble import AdaBoostRegressor
ABR=AdaBoostRegressor()
ABR.fit(x_train,y_train)
predABR= ABR.predict(x_test)
predtrain=ABR.predict(x_train)
print(ABR)
print("R2_score:",r2_score(y_test,predABR))
print("R2 score on Training data:",r2_score(y_train,predtrain)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,predABR))
print("Mean Squared Error:",mean_squared_error(y_test,predABR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,predABR)))
# Out:
# AdaBoostRegressor()
# R2_score: 0.9973553183748004
# R2 score on Training data: 99.82452868793757
# Mean Absolute Error: 0.041474351240807415
# Mean Squared Error: 0.0027158076810735845
# Root Mean Squared Error: 0.052113411719763504

# %% [markdown]
# All the model showing high coefficient of determination except KNN,lasso .The Best model performance shown by Random Forest Regressor, Gradient Boosting Regressor ExtraTreesRegressor with least Error,
# 2.LR model is showing great result but MSE is on higher side of Mean Squared Error: 8.423360587069696e-08 so also not consider for prediction on unseen dataset

# %% [markdown]
# # Spliting train test data using Cross validation score¶

# %%
from sklearn.model_selection import cross_val_score

# %%
#Checking cv score for Random Forest Regressor
score= cross_val_score(RFR,x,y)
print(score)
print(score.mean())
print("The difference between Accuracy score and Cross validation score: ",r2_score(y_test,predRFR)-score.mean())
# Out:
# [-4.11187216 -0.61601782 -0.22356886 -0.84970378 -2.60222614]
# -1.680677751530872
# The difference between Accuracy score and Cross validation score:  2.678960105791097

# %%
#Checking cv score for Extra Tree Regressor
score1= cross_val_score(ET,x,y)
print(score1)
print(score1.mean())
print("The difference between Accuracy score and Cross validation score: ",r2_score(y_test,predET)-score1.mean())
# Out:
# [-4.18395883  0.80405593  0.80895585  0.91651628 -2.59162349]
# -0.849210852967779
# The difference between Accuracy score and Cross validation score:  1.8486171823429252

# %%
#checking  CV for GBR
score2=cross_val_score(GBR,x,y)
print(score2)
print(score2.mean())
print("Difference between Accuracy score and Cross validation score is :",r2_score(y_test,predGBR)-score2.mean())
# Out:
# [-3.4950018   0.27538362 -0.02593488 -0.30525788 -2.26501192]
# -1.1631645721094779
# Difference between Accuracy score and Cross validation score is : 2.1615795531516557

# %%
#checking  CV for Decision Tree Regressor
score3=cross_val_score(dtr,x,y)
print(score3)
print(score3.mean())
print("Difference between Accuracy score and Cross validation score is :",r2_score(y_test,preddtr)-score3.mean())
# Out:
# [-3.72913819 -0.38695304 -0.14243374 -0.76455732 -2.08271262]
# -1.4211589810451541
# Difference between Accuracy score and Cross validation score is : 2.4149255885420944

# %%
#checking  CV for linear Regressor
score4=cross_val_score(LR,x,y)
print(score4)
print(score4.mean())
print("Difference between Accuracy score and Cross validation score is :",r2_score(y_test,predLR)-score4.mean())
# Out:
# [0.99999926 0.99999853 0.99999827 0.99999522 0.99999934]
# 0.9999981259532401
# Difference between Accuracy score and Cross validation score is : 1.7920192028064719e-06

# %%
#checking  CV for ridge Regressor
score5=cross_val_score(rd,x,y)
print(score5)
print(score5.mean())
print("Difference between Accuracy score and Cross validation score is :",r2_score(y_test,predrd)-score5.mean())
# Out:
# [0.93809384 0.98324857 0.99092866 0.98382104 0.9930155 ]
# 0.9778215210561368
# Difference between Accuracy score and Cross validation score is : 0.021901784508656652

# %%
#checking  CV for Ababoosting Regressor
score6=cross_val_score(ABR,x,y)
print(score6)
print(score6.mean())
print("Difference between Accuracy score and Cross validation score is :",r2_score(y_test,predABR)-score6.mean())
# Out:
# [-4.62478137 -1.07845748 -1.88494992 -1.84239854 -3.0712802 ]
# -2.5003735012065222
# Difference between Accuracy score and Cross validation score is : 3.4977288195813228

# %%
#checking  CV for Bagging Regressor
score7=cross_val_score(BR,x,y)
print(score7)
print(score7.mean())
print("Difference between Accuracy score and Cross validation score is :",r2_score(y_test,predBR)-score7.mean())
# Out:
# [-4.08331164 -0.64731967 -0.31470866 -0.82433405 -2.60979072]
# -1.6958929456847827
# Difference between Accuracy score and Cross validation score is : 2.694032991290009

# %% [markdown]
# The Best cross validation result is shown by linear regression and ridge as least biasness and high variance data sample provided for training the model with high performance on unseen data

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters = {"fit_intercept" :[True, False],
              "copy_X" :[True, False],
              "n_jobs" : [None,1,-1],
              "positive" :[True, False]}

# %%
GCV= GridSearchCV(LinearRegression(),parameters, cv = 5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearRegression(),
#              param_grid={'copy_X': [True, False],
#                          'fit_intercept': [True, False],
#                          'n_jobs': [None, 1, -1], 'positive': [True, False]})

# %%
GCV.best_params_
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
#Checking LR  Model with parameter tunning

# %%
model_lr=LinearRegression(fit_intercept=True, copy_X = True, n_jobs=None, positive=False)
model_lr.fit(x_train,y_train)
prediLR=model_lr.predict(x_test)
preditrain=model_lr.predict(x_train)
print(model_lr)
print("R2 score: ",r2_score(y_test,prediLR))
print("R2 score on training dataset: ",r2_score(y_train,preditrain))
print("Mean Squared Error: ",mean_squared_error(y_test,prediLR))
print("Mean Absolute Error:",mean_absolute_error(y_test,prediLR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,prediLR)))
# Out:
# LinearRegression()
# R2 score:  0.9999999179724429
# R2 score on training dataset:  0.999999941718157
# Mean Squared Error:  8.423360587069696e-08
# Mean Absolute Error: 0.0002603136167180331
# Root Mean Squared Error: 0.00029023026353345194

# %%
model_lr=LinearRegression(fit_intercept=True, copy_X = True, n_jobs=None, positive=False)
model_lr.fit(x_train,y_train)
prediLR=model_lr.predict(x_test)
preditrain=model_lr.predict(x_train)
print(model_lr)
print("R2 score: ",r2_score(y_test,prediLR))
print("R2 score on training dataset: ",r2_score(y_train,preditrain))
print("Mean Squared Error: ",mean_squared_error(y_test,prediLR))
print("Mean Absolute Error:",mean_absolute_error(y_test,prediLR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,prediLR)))
# Out:
# LinearRegression(n_jobs=1)
# R2 score:  0.9999999179724429
# R2 score on training dataset:  0.999999941718157
# Mean Squared Error:  8.423360587069696e-08
# Mean Absolute Error: 0.0002603136167180331
# Root Mean Squared Error: 0.00029023026353345194

# %% [markdown]
# # Saving the model

# %%
import pickle
filename1="World_happiness_score1.pkl"
pickle.dump(model_lr,open(filename1,"wb"))

# %%
load_model1=pickle.load(open("World_happiness_score1.pkl","rb"))
result1=load_model1.score(x_test,y_test)
print(result1*100)
# Out:
# 99.99999179724429

# %%
conclusion1 =pd.DataFrame([load_model1.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
conclusion1
# Out:
#                  0         1         2         3         4         5   \
# Predicted  3.988726  4.642235  5.758594  5.140432  7.363595  4.714779
# Original   3.989000  4.642000  5.759000  5.140000  7.364000  4.715000
#
#                  6         7         8         9   ...        20        21  \
# Predicted  3.780789  4.875986  4.507107  5.101609  ...  6.122819  7.286002
# Original   3.781000  4.876000  4.507000  5.102000  ...  6.123000  7.286000
#
#                  22        23        24        25        26        27  \
# Predicted  5.097555  6.810171  5.695245  4.884422  4.971145  6.669666
# Original   5.098000  6.810000  5.695000  4.885000  4.971000  6.670000
#
#                  28        29
# Predicted  5.987107  3.955641
# Original   5.987000  3.956000
#
# [2 rows x 30 columns]

# %%
#Checking for ridge parameters

parameters1 = {"alpha" :[1.0,0.05,.4,2],
              "solver":["auto", "svd", "cholesky", "lsqr", "sparse_cg", "sag", "saga"," lbfgs"],
               "positive":[True,False],
               "fit_intercept":[True,False],
              "random_state" : [1,4,10,20]}     

GCV1= GridSearchCV(Ridge(),parameters1, cv = 5)

# %%
GCV1.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1.0, 0.05, 0.4, 2],
#                          'fit_intercept': [True, False],
#                          'positive': [True, False],
#                          'random_state': [1, 4, 10, 20],
#                          'solver': ['auto', 'svd', 'cholesky', 'lsqr',
#                                     'sparse_cg', 'sag', 'saga', ' lbfgs']})

# %%
GCV1.best_params_
# Out:
# {'alpha': 1.0,
#  'fit_intercept': True,
#  'positive': True,
#  'random_state': 1,
#  'solver': 'auto'}

# %%
model_rd=Ridge(alpha = 1.0,solver ="auto",positive= True,fit_intercept= True, random_state=1)
model_rd.fit(x_train,y_train)
predird=model_rd.predict(x_test)
preditrain=model_rd.predict(x_train)
print(model_rd)
print("R2 score: ",r2_score(y_test,predird))
print("R2 score on training dataset: ",r2_score(y_train,preditrain))
print("Mean Squared Error: ",mean_squared_error(y_test,predird))
print("Mean Absolute Error:",mean_absolute_error(y_test,predird))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,predird)))
# Out:
# Ridge(positive=True, random_state=1)
# R2 score:  0.9999708687279723
# R2 score on training dataset:  0.9999754932578472
# Mean Squared Error:  2.9914728328189407e-05
# Mean Absolute Error: 0.004834732604921014
# Root Mean Squared Error: 0.005469435832715236

# %% [markdown]
# # Saving the model

# %%
import pickle
filename2="World_happiness_score2.pkl"
pickle.dump(model_lr,open(filename2,"wb"))

# %%
load_model2=pickle.load(open("World_happiness_score2.pkl","rb"))
result2=load_model2.score(x_test,y_test)
print(result2*100)
# Out:
# 99.99999179724429

# %%
conclusion2 =pd.DataFrame([load_model2.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
conclusion2
# Out:
#                  0         1         2         3         4         5   \
# Predicted  3.988726  4.642235  5.758594  5.140432  7.363595  4.714779
# Original   3.989000  4.642000  5.759000  5.140000  7.364000  4.715000
#
#                  6         7         8         9   ...        20        21  \
# Predicted  3.780789  4.875986  4.507107  5.101609  ...  6.122819  7.286002
# Original   3.781000  4.876000  4.507000  5.102000  ...  6.123000  7.286000
#
#                  22        23        24        25        26        27  \
# Predicted  5.097555  6.810171  5.695245  4.884422  4.971145  6.669666
# Original   5.098000  6.810000  5.695000  4.885000  4.971000  6.670000
#
#                  28        29
# Predicted  5.987107  3.955641
# Original   5.987000  3.956000
#
# [2 rows x 30 columns]

# %%
#Checking for ExtraTrees Regressor parameters

parameters2 = {"criterion" : ["squared_error","absolute_error","friedman_mse","poisson"],
             "random_state" : [10,50,1000],
             "max_depth" : [None,10,20],
             "n_jobs" : [-2,-1,1],
             "n_estimators" : [50,100,200,300]}

GCV2= GridSearchCV(ExtraTreesRegressor(),parameters2, cv = 5)

# %%
GCV2.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesRegressor(),
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_depth': [None, 10, 20],
#                          'n_estimators': [50, 100, 200, 300],
#                          'n_jobs': [-2, -1, 1],
#                          'random_state': [10, 50, 1000]})

# %%
GCV2.best_params_
# Out:
# {'criterion': 'poisson',
#  'max_depth': None,
#  'n_estimators': 50,
#  'n_jobs': -2,
#  'random_state': 1000}

# %%
# Again checking the parameter given by Grid search CV for Extra Trees Regressor

final_model=ExtraTreesRegressor(criterion="poisson",random_state=1000,max_depth= None,n_jobs=-2,n_estimators=50)
final_model.fit(x_train,y_train)
predET=final_model.predict(x_test)
predtrain=final_model.predict(x_train)
print(final_model)
print("R2_score:",r2_score(y_test,predET))
print("R2 score on Training data:",r2_score(y_train,predtrain)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,predET))
print("Mean Squared Error:",mean_squared_error(y_test,predET))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,predET)))
# Out:
# ExtraTreesRegressor(criterion='poisson', n_estimators=50, n_jobs=-2,
#                     random_state=1000)
# R2_score: 0.9993897784165532
# R2 score on Training data: 100.0
# Mean Absolute Error: 0.018394666666666663
# Mean Squared Error: 0.0006266328799999784
# Root Mean Squared Error: 0.025032636297441353

# %% [markdown]
# From above all the model trained and validate we can found linear regression is best with accuracy score of 99.99 but MSE error is around 8 ridge is also showing best accuracy with least error and ET Regression is the best of all three used model due to high accuracy score with minimum error rate

# %% [markdown]
# # Saving the model

# %%
import joblib

# %%
import pickle
filename="World_happiness.pkl"
pickle.dump(final_model,open(filename,"wb"))# saved model

# %%
import pickle
load_model=pickle.load(open("World_happiness.pkl","rb"))
result=load_model.score(x_test,y_test)
print(result*100)
# Out:
# 99.93897784165532

# %%
conclusion =pd.DataFrame([load_model.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
conclusion
# Out:
#                 0        1        2        3        4        5        6   \
# Predicted  3.92712  4.62898  5.74098  5.17916  7.34802  4.72478  3.75626
# Original   3.98900  4.64200  5.75900  5.14000  7.36400  4.71500  3.78100
#
#                 7       8        9   ...      20      21       22      23  \
# Predicted  4.90506  4.4479  5.16348  ...  6.1086  7.2729  5.10444  6.7838
# Original   4.87600  4.5070  5.10200  ...  6.1230  7.2860  5.09800  6.8100
#
#                 24       25       26       27       28       29
# Predicted  5.66884  4.91206  4.95528  6.67082  5.98754  3.95532
# Original   5.69500  4.88500  4.97100  6.67000  5.98700  3.95600
#
# [2 rows x 30 columns]
