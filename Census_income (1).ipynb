# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing Dataset

# %%
df = pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Census%20Income/Census%20Income.csv')
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# # Checking Dimensions

# %%
df.shape
# Out:
# (32560, 15)

# %% [markdown]
# No of rows = 32560, columns = 15

# %% [markdown]
# # Checking rows on random basis

# %%
df.sample(20)
# Out:
#        Age          Workclass  Fnlwgt      Education  Education_num  \
# 28039   61            Private  232808           10th              6
# 14075   51        Federal-gov  140035        HS-grad              9
# 7272    27            Private  245661        HS-grad              9
# 5707    43   Self-emp-not-inc  145441    Prof-school             15
# 9767    36            Private  218542   Some-college             10
# 13804   34       Self-emp-inc  242984      Bachelors             13
# 18227   64            Private  126233        HS-grad              9
# 5945    34          Local-gov  210164   Some-college             10
# 27155   34   Self-emp-not-inc  204052        HS-grad              9
# 13412   25            Private  169100        Masters             14
# 10085   34   Self-emp-not-inc  152493        HS-grad              9
# 6543    61            Private  132972            9th              5
# 15328   18            Private  133055        HS-grad              9
# ...

# %%
#Checking head of the table
df.head(10)
# Out:
#    Age          Workclass  Fnlwgt      Education  Education_num  \
# 0   50   Self-emp-not-inc   83311      Bachelors             13
# 1   38            Private  215646        HS-grad              9
# 2   53            Private  234721           11th              7
# 3   28            Private  338409      Bachelors             13
# 4   37            Private  284582        Masters             14
# 5   49            Private  160187            9th              5
# 6   52   Self-emp-not-inc  209642        HS-grad              9
# 7   31            Private   45781        Masters             14
# 8   42            Private  159449      Bachelors             13
# 9   37            Private  280464   Some-college             10
#
#            Marital_status          Occupation    Relationship    Race  \
# 0      Married-civ-spouse     Exec-managerial         Husband   White
# 1                Divorced   Handlers-cleaners   Not-in-family   White
# ...

# %%
#Checking tail of the table
df.tail(10)
# Out:
#        Age      Workclass  Fnlwgt      Education  Education_num  \
# 32550   32        Private   34066           10th              6
# 32551   43        Private   84661      Assoc-voc             11
# 32552   32        Private  116138        Masters             14
# 32553   53        Private  321865        Masters             14
# 32554   22        Private  310152   Some-college             10
# 32555   27        Private  257302     Assoc-acdm             12
# 32556   40        Private  154374        HS-grad              9
# 32557   58        Private  151910        HS-grad              9
# 32558   22        Private  201490        HS-grad              9
# 32559   52   Self-emp-inc  287927        HS-grad              9
#
#             Marital_status          Occupation    Relationship  \
# 32550   Married-civ-spouse   Handlers-cleaners         Husband
# 32551   Married-civ-spouse               Sales         Husband
# 32552        Never-married        Tech-support   Not-in-family
# ...

# %% [markdown]
# # List of columns

# %%
df.columns.tolist()
# Out:
# ['Age',
#  'Workclass',
#  'Fnlwgt',
#  'Education',
#  'Education_num',
#  'Marital_status',
#  'Occupation',
#  'Relationship',
#  'Race',
#  'Sex',
#  'Capital_gain',
#  'Capital_loss',
#  'Hours_per_week',
#  'Native_country',
#  'Income']

# %%
#checking the datatypes of columns
df.dtypes
# Out:
# Age                int64
# Workclass         object
# Fnlwgt             int64
# Education         object
# Education_num      int64
# Marital_status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Capital_gain       int64
# Capital_loss       int64
# Hours_per_week     int64
# Native_country    object
# Income            object
# dtype: object

# %% [markdown]
# Observation : Here both numerical and categorical columns are present as (int64,object,float64) in dataset

# %%
#checking the value count for each columns

for i in df.columns:
    print("Unique Values",df[i].value_counts())
    print("\n")
# Out:
# Unique Values 36    898
# 31    888
# 34    886
# 23    877
# 35    876
#      ...
# 83      6
# 88      3
# 85      3
# 86      1
# 87      1
# Name: Age, Length: 73, dtype: int64
#
#
# Unique Values  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64
#
#
# Unique Values 164190    13
# 203488    13
# 123011    13
# 148995    12
# 126675    12
#           ..
# 325573     1
# 140176     1
# 318264     1
# 329205     1
# 257302     1
# Name: Fnlwgt, Length: 21647, dtype: int64
#
#
# Unique Values  HS-grad         10501
#  Some-college     7291
#  Bachelors        5354
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
# ...

# %% [markdown]
# Observation : There is  value "?" 1843 rows in Occupation column

# %% [markdown]
# # No of unique values in column

# %%
df.nunique().to_frame('No of Unique Values')
# Out:
#                 No of Unique Values
# Age                              73
# Workclass                         9
# Fnlwgt                        21647
# Education                        16
# Education_num                    16
# Marital_status                    7
# Occupation                       15
# Relationship                      6
# Race                              5
# Sex                               2
# Capital_gain                    119
# Capital_loss                     92
# Hours_per_week                   94
# Native_country                   42
# Income                            2

# %% [markdown]
# Observation: Target variable has only 2 unique values

# %%
df.replace(' ?' ,np.NaN,inplace=True)

# %% [markdown]
# # np.nan,None,NaN,others

# %%
print('Dataset columns with null values:\n', df.isnull().sum())
# Out:
# Dataset columns with null values:
#  Age                  0
# Workclass         1836
# Fnlwgt               0
# Education            0
# Education_num        0
# Marital_status       0
# Occupation        1843
# Relationship         0
# Race                 0
# Sex                  0
# Capital_gain         0
# Capital_loss         0
# Hours_per_week       0
# Native_country     583
# Income               0
# dtype: int64

# %%
print('Dataset with Total null values :\n', df.isnull().sum().sum())
# Out:
# Dataset with Total null values :
#  4262

# %%
#lets visualize null value using heatmap
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# Observation: Since the total no of rows is 32560, and the no of null values are 4262 low we can drop the null values instead of replacing with mode as replacement can bring biasness

# %%
na_df=df.dropna()

# %%
print("The loss of data in percentage",((df.shape[0]-na_df.shape[0])/df.shape[0])*100)
# Out:
# The loss of data in percentage 7.367936117936118

# %% [markdown]
# Observation lost data is less than 10%  Since the total no of rows is 32560, and the no of null values are low we can drop the null values instead of replacing with mode as replacement can bring biasness

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30161 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             30161 non-null  int64
#  1   Workclass       30161 non-null  object
#  2   Fnlwgt          30161 non-null  int64
#  3   Education       30161 non-null  object
#  4   Education_num   30161 non-null  int64
#  5   Marital_status  30161 non-null  object
#  6   Occupation      30161 non-null  object
#  7   Relationship    30161 non-null  object
#  8   Race            30161 non-null  object
#  9   Sex             30161 non-null  object
#  10  Capital_gain    30161 non-null  int64
#  11  Capital_loss    30161 non-null  int64
#  12  Hours_per_week  30161 non-null  int64
#  13  Native_country  30161 non-null  object
#  14  Income          30161 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# Observation: Age, Fnlwgt,Educationan_num,Capital_gain, Capital_loss, Hours_per_week are integer values rest are object

# %% [markdown]
# # Separating Numerical and Categorical Column

# %%
cat_col = []
for i in df.dtypes.index:
    if df.dtypes[i]=='object':
        cat_col.append(i)
print('Categorical Columns: ',cat_col)
print('\n')

num_col = []
for i in df.dtypes.index:
    if df.dtypes[i]!='object':
        num_col.append(i)
print('Numerical Columns: ',num_col)
# Out:
# Categorical Columns:  ['Workclass', 'Education', 'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex', 'Native_country', 'Income']
#
#
# Numerical Columns:  ['Age', 'Fnlwgt', 'Education_num', 'Capital_gain', 'Capital_loss', 'Hours_per_week']

# %% [markdown]
# # Checking the statistical summary

# %%
#Checking the statistical summary of numerical columns
df.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  30161.000000  3.016100e+04   30161.000000  30161.000000  30161.000000
# mean      38.437883  1.897976e+05      10.121216   1091.971984     88.375419
# std       13.134882  1.056527e+05       2.549983   7406.466659    404.304753
# min       17.000000  1.376900e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.176280e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.784290e+05      10.000000      0.000000      0.000000
# 75%       47.000000  2.376300e+05      13.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    30161.000000
# mean        40.931269
# std         11.980182
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# Observation:
#
# Count is same for all variables hence no null values
#
# All variables have outliers

# %%
plt.figure(figsize=(22,10))
sns.heatmap(df.describe(),annot=True,fmt="0.2f",linewidth=0.2,linecolor="black",cmap="Blues_r")
plt.xlabel("Features Names",fontsize=14)
plt.ylabel("Descriptive Stats",fontsize=14)
plt.title("Descriptive Graph",fontsize=20)
plt.show()

# %%
# Statistical summary of dataset including categorical cols
df.describe(include='all').T
# Out:
#                   count unique                  top   freq           mean  \
# Age             30161.0    NaN                  NaN    NaN      38.437883
# Workclass         30161      7              Private  22286            NaN
# Fnlwgt          30161.0    NaN                  NaN    NaN  189797.556547
# Education         30161     16              HS-grad   9840            NaN
# Education_num   30161.0    NaN                  NaN    NaN      10.121216
# Marital_status    30161      7   Married-civ-spouse  14065            NaN
# Occupation        30161     14       Prof-specialty   4038            NaN
# Relationship      30161      6              Husband  12463            NaN
# Race              30161      5                White  25932            NaN
# Sex               30161      2                 Male  20379            NaN
# Capital_gain    30161.0    NaN                  NaN    NaN    1091.971984
# Capital_loss    30161.0    NaN                  NaN    NaN      88.375419
# ...

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # Univariate Analysis

# %%
#Checking count of target variable Attrition
sns.countplot(x="Income",data=df)
print(df["Income"].value_counts())
# Out:
#  <=50K    22653
#  >50K      7508
# Name: Income, dtype: int64

# %%
for i in cat_col:
    plt.figure(figsize=(6,2),facecolor="white")
    sns.countplot(x=df[i],data=df)
    plt.xticks(rotation=90, fontsize=10)
    print(df[i].value_counts())
    print("\n")
plt.show()
# Out:
#  Private             22286
#  Self-emp-not-inc     2499
#  Local-gov            2067
#  State-gov            1278
#  Self-emp-inc         1074
#  Federal-gov           943
#  Without-pay            14
# Name: Workclass, dtype: int64
#
#
#  HS-grad         9840
#  Some-college    6678
#  Bachelors       5043
#  Masters         1627
#  Assoc-voc       1307
#  11th            1048
#  Assoc-acdm      1008
#  10th             820
#  7th-8th          557
#  Prof-school      542
#  9th              455
#  12th             377
#  Doctorate        375
#  5th-6th          288
#  1st-4th          151
#  Preschool         45
# Name: Education, dtype: int64
#
#
#  Married-civ-spouse       14065
#  Never-married             9725
#  Divorced                  4214
#  Separated                  939
#  Widowed                    827
#  Married-spouse-absent      370
#  Married-AF-spouse           21
# Name: Marital_status, dtype: int64
#
#
#  Prof-specialty       4038
#  Craft-repair         4030
# ...

# %% [markdown]
# # Checking the distribution of the data by using distplot

# %%
#Checking the distribution of the data of numerical column  by using distplot
plt.figure(figsize=(20,10), facecolor = 'grey')
pltno = 1
for i in num_col:
    if pltno<=6:
        plt.subplot(3,2,pltno)
        sns.distplot(df[i],color='r')
        plt.xlabel(i,fontsize=12)
        plt.yticks(rotation = 90, fontsize=10)
    pltno+=1
plt.tight_layout()

# %% [markdown]
# # Bivariate Analysis

# %%
plt.figure(figsize=(15, 20))

subplot_index = 1

for c in cat_col:
    plt.subplot(6, 2, subplot_index)
    sns.countplot(x=df[c], hue='Income', data=df, palette='husl')
    plt.xlabel(c, fontsize=20)
    plt.ylabel('Count', fontsize=20)
    plt.xticks(rotation=90, fontsize=10)
    plt.title('Countplot of {} by income'.format(c), fontsize=20)
    subplot_index += 1

plt.tight_layout()
plt.show()

# %% [markdown]
# Observation:
# In workcalss count of pvt employees is higher with income bracket <=50k
#
# In education HS garde is maximum followed by some college and age bracket is <=50k
#
# In marital_status count of never married category is high with salary <=50K followed by Married-civ-spouse have nearly equal count of income >50k and <=50k
#
# In Occupation count of Adm clerical,Craft Repair, Other service is high with <50k salary whereas >50k salary is highest for prof speciality
#
# In Relationship the persons with husbamd are high with the income >50k and the persons who are not in family have highest count of income <=50k.
#
# In Races White race is higher
#
# In sex Male count is greater than female count also for the Income >50k.
#
# In native_country the United States persons are having more people who have income >50k
#
# In Income the data is biased towards income <=50k

# %%
#Comparing Income  with other columns using regressor plot to find any relationship 
plt.figure(figsize=(20,25))
p=1
for i in num_col:
    if p<=6:
        plt.subplot(3,2,p)
        sns.regplot(x=df[i], y="Capital_loss", data=df, color="g")
        plt.xlabel(i)
        plt.ylabel("Capital_loss")
    p+=1
plt.show()

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(df)

# %% [markdown]
# # Checking for outliers

# %%
plt.figure(figsize=(20,40),facecolor='grey')
pltno = 1
for i in num_col:
    if pltno<=6:
        plt.subplot(3,2,pltno)
        sns.boxplot(df[i],palette='gnuplot')
        plt.xlabel(i,fontsize=15)
        plt.yticks(rotation = 0,fontsize=10)
    pltno+=1
plt.tight_layout()

# %%
from scipy.stats import zscore
outliers = df[['Age','Fnlwgt','Education_num','Capital_gain','Capital_loss','Hours_per_week']]
z = np.abs(zscore(outliers))
z
# Out:
#             Age    Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# 0      0.880275  1.007909       1.128961      0.147437       0.21859
# 1      0.033338  0.244659       0.439703      0.147437       0.21859
# 2      1.108678  0.425206       1.224035      0.147437       0.21859
# 3      0.794682  1.406626       1.128961      0.147437       0.21859
# 4      0.109472  0.897147       1.521127      0.147437       0.21859
# ...         ...       ...            ...           ...           ...
# 32555  0.870817  0.638938       0.736795      0.147437       0.21859
# 32556  0.118931  0.335288       0.439703      0.147437       0.21859
# 32557  1.489350  0.358611       0.439703      0.147437       0.21859
# 32558  1.251489  0.110670       0.439703      0.147437       0.21859
# 32559  1.032544  0.928808       0.439703      1.881094       0.21859
#
#        Hours_per_week
# 0            2.331495
# 1            0.077735
# 2            0.077735
# 3            0.077735
# ...

# %%
np.where(z>3)
# Out:
# (array([    9,    21,    25, ..., 30087, 30117, 30124], dtype=int64),
#  array([5, 4, 5, ..., 5, 1, 3], dtype=int64))

# %%
z.iloc[9,5]
# Out:
# 3.2611674864312907

# %%
df1 = df[(z<3).all(axis=1)]
df1.shape
# Out:
# (27620, 15)

# %%
per_data_loss = ((df.shape[0] - df1.shape[0]) / df.shape[0]*100)

# %%
per_data_loss
# Out:
# 8.424786976559133

# %%
#Checking for Skewness
df1.skew()
# Out:
# Age                0.448146
# Fnlwgt             0.630041
# Education_num     -0.163054
# Capital_gain       4.857802
# Capital_loss      29.005162
# Hours_per_week    -0.281712
# dtype: float64

# %%
df1['Capital_gain']=np.cbrt(df1['Capital_gain'])
df1['Capital_loss']=np.cbrt(df1['Capital_loss'])

# %%
df1.skew()
# Out:
# Age                0.448146
# Fnlwgt             0.630041
# Education_num     -0.163054
# Capital_gain       3.344613
# Capital_loss      25.310972
# Hours_per_week    -0.281712
# dtype: float64

# %%
# Again checking data has been distributed in numerical column after removing skewness
plt.figure(figsize=(20,25),facecolor='Grey')
p=1
for i in num_col:
    if p<7:
        plt.subplot(3,2,p)
        sns.distplot(df[i],color='g')
        plt.xlabel(i)
    p+=1
plt.show()

# %% [markdown]
# # Feature Preprocessing

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()

for i in df1:
    if df1[i].dtypes=="object":
        df1[i]=LE.fit_transform(df1[i].values.reshape(-1,1))
        
        
df1
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50          4   83311          8             13               2
# 1       38          2  215646         10              9               0
# 2       53          2  234721          1              7               2
# 3       28          2  338409          8             13               2
# 4       37          2  284582         11             14               2
# ...    ...        ...     ...        ...            ...             ...
# 32555   27          2  257302          6             12               2
# 32556   40          2  154374         10              9               2
# 32557   58          2  151910         10              9               6
# 32558   22          2  201490         10              9               4
# 32559   52          3  287927         10              9               2
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# ...

# %% [markdown]
# # Correlation b/w target variable and independent variable

# %% [markdown]
# # Multicollinearity

# %%
cor=df1.corr()
cor
# Out:
#                      Age  Workclass    Fnlwgt  Education  Education_num  \
# Age             1.000000   0.072717 -0.074255   0.003276       0.045711
# Workclass       0.072717   1.000000 -0.030695   0.015334       0.034387
# Fnlwgt         -0.074255  -0.030695  1.000000  -0.022207      -0.039413
# Education       0.003276   0.015334 -0.022207   1.000000       0.345230
# Education_num   0.045711   0.034387 -0.039413   0.345230       1.000000
# Marital_status -0.294029  -0.030673  0.033210  -0.038066      -0.052174
# Occupation     -0.007536   0.016044 -0.001245  -0.039456       0.086408
# Relationship   -0.248684  -0.067201  0.008574  -0.013417      -0.093514
# Race            0.023453   0.041820 -0.013698   0.013207       0.029708
# Sex             0.078574   0.072607  0.026404  -0.029021       0.001368
# Capital_gain    0.126792   0.011116 -0.005965   0.025443       0.132475
# Capital_loss    0.020516  -0.007954 -0.001406  -0.003196       0.006936
# ...

# %%
#Visualizing the correlation marix by using  heatmap

plt.figure(figsize=(26,14))
sns.heatmap(cor,annot=True,fmt="0.2f",linewidth = 0.2,linecolor="black", cmap="Blues_r")
plt.xlabel("Figure",fontsize=14)
plt.ylabel("Features_Name", fontsize=14)
plt.title("Descriptive Graph", fontsize=20)
plt.show()

# %% [markdown]
# # Visulaizing correlation b/w label and features

# %%
plt.figure(figsize=(22,7))
df1.corr()['Income'].sort_values(ascending = False).drop(['Income']).plot(kind='bar',color='g')
plt.xlabel('Features',fontsize=15)
plt.ylabel('Features',fontsize=15)
plt.title('Correlation b/w Label and Features')
plt.show()

# %% [markdown]
# Observation: Of the the available features correlation with income is strongest in case of capital_gains and negatively correlated in case of relationship

# %%
#Dropping Capital Loss Feature as it is highly skewed and is not correlated with Income
df1 = df1.drop('Capital_loss',axis=1)

# %%
df1.skew()
# Out:
# Age               0.448146
# Workclass         1.192474
# Fnlwgt            0.630041
# Education        -1.088798
# Education_num    -0.163054
# Marital_status   -0.042890
# Occupation        0.115222
# Relationship      0.776258
# Race             -2.500768
# Sex              -0.710201
# Capital_gain      3.344613
# Hours_per_week   -0.281712
# Native_country   -4.231662
# Income            1.277084
# dtype: float64

# %% [markdown]
# # Separating Label and Features

# %%
x = df1.iloc[:,0:13]
y = df1.iloc[:,-1]

# %%
x
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50          4   83311          8             13               2
# 1       38          2  215646         10              9               0
# 2       53          2  234721          1              7               2
# 3       28          2  338409          8             13               2
# 4       37          2  284582         11             14               2
# ...    ...        ...     ...        ...            ...             ...
# 32555   27          2  257302          6             12               2
# 32556   40          2  154374         10              9               2
# 32557   58          2  151910         10              9               6
# 32558   22          2  201490         10              9               4
# 32559   52          3  287927         10              9               2
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Hours_per_week  \
# ...

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32555    0
# 32556    1
# 32557    0
# 32558    0
# 32559    1
# Name: Income, Length: 27620, dtype: int32

# %% [markdown]
# # Scaling Using Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#             Age  Workclass    Fnlwgt  Education  Education_num  \
# 0      0.931625   1.905857 -1.078291  -0.355643       1.186577
# 1     -0.001969  -0.200239  0.321873   0.243385      -0.459369
# 2      1.165023  -0.200239  0.523695  -2.452240      -1.282342
# 3     -0.779964  -0.200239  1.620760  -0.355643       1.186577
# 4     -0.079768  -0.200239  1.051247   0.542899       1.598063
# ...         ...        ...       ...        ...            ...
# 27615 -0.857763  -0.200239  0.762612  -0.954670       0.775090
# 27616  0.153630  -0.200239 -0.326412   0.243385      -0.459369
# 27617  1.554021  -0.200239 -0.352482   0.243385      -0.459369
# 27618 -1.246761  -0.200239  0.172096   0.243385      -0.459369
# 27619  1.087224   0.852809  1.086638   0.243385      -0.459369
#
#        Marital_status  Occupation  Relationship      Race       Sex  \
# 0           -0.391191   -0.725175     -0.904594  0.386109  0.706089
# 1           -1.717492   -0.230477     -0.281763  0.386109  0.706089
# ...

# %% [markdown]
# # Checking Variance Inflation Factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['VIF Values'] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['Features']=x.columns
vif
# Out:
#     VIF Values        Features
# 0     1.176428             Age
# 1     1.013000       Workclass
# 2     1.013107          Fnlwgt
# 3     1.147804       Education
# 4     1.201029   Education_num
# 5     1.138402  Marital_status
# 6     1.019030      Occupation
# 7     1.665957    Relationship
# 8     1.035075            Race
# 9     1.557486             Sex
# 10    1.040861    Capital_gain
# 11    1.141021  Hours_per_week
# 12    1.026944  Native_country

# %% [markdown]
# # Applying SMOTE to overcome Oversampling Problem

# %%
y.value_counts()
# Out:
# 0    21242
# 1     6378
# Name: Income, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
SM=SMOTE()
x,y = SM.fit_resample(x,y)

# %% [markdown]
# # Determination of Income >50k and <50k  - Classification Problem

# %% [markdown]
# # Modelling

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier , ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier , AdaBoostClassifier, BaggingClassifier
from sklearn.metrics import classification_report , confusion_matrix, roc_curve, accuracy_score
from sklearn.model_selection import cross_val_score

# %%
# List of models to evaluate
models = [
    ('Logistic Regression', LogisticRegression()),
    ('Gradient Boosting', GradientBoostingClassifier()),
    ('Random Forest', RandomForestClassifier()),
    ('KNN', KNeighborsClassifier()),
    ('Extra Tree', ExtraTreesClassifier()),
    ('Bagging', BaggingClassifier()),
    ('AdaBoost', AdaBoostClassifier()),
    ('SVC', SVC())]

# Variables to store the best results
best_random_states = []
best_accuracies = []

# Evaluate each model
for model_name, model in models:
    maxAcc = 0
    maxRs = 0
    for i in range(1, 100):
        x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=i)
        model.fit(x_train, y_train)
        pred = model.predict(x_test)
        acc = accuracy_score(y_test, pred)
        if acc > maxAcc:
            maxAcc = acc
            maxRs = i
    best_random_states.append((model_name, maxRs))
    best_accuracies.append((model_name, maxAcc))
    print("Max Accuracy score ",model_name, "is:", maxAcc, "on Random State", maxRs)

# Print summary of results
print("\nSummary of best random states and accuracies for each model:")
for i in range(len(models)):
    model_name = models[i][0]
    print("Maximum Accuracy score is", best_accuracies[i][1], "on Random_state", best_random_states[i][1])
# Out:
# Max r2 score for  Logistic Regression is: 0.7681625608033893 on Random State 55
# Max r2 score for  Gradient Boosting is: 0.8729013023693708 on Random State 11
# Max r2 score for  Random Forest is: 0.9033422250117684 on Random State 61
# Max r2 score for  KNN is: 0.8615251843715676 on Random State 90
# Max r2 score for  Extra Tree is: 0.9074219362937392 on Random State 83
# Max r2 score for  Bagging is: 0.888278675662953 on Random State 36
# Max r2 score for  AdaBoost is: 0.8592499607720069 on Random State 83
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[77], line 23
#      21 x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=i)
#      22 model.fit(x_train, y_train)
# ---> 23 pred = model.predict(x_test)
#      24 acc = accuracy_score(y_test, pred)
#      25 if acc > maxAcc:
#
# ...

# %% [markdown]
# # Train Test Split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=55)

# %% [markdown]
# # Logistics Regression

# %%
LR = LogisticRegression()
LR.fit(x_train,y_train)
predLR = LR.predict(x_test)
print(accuracy_score(y_test,predLR))
print(confusion_matrix(y_test,predLR))
print(classification_report(y_test,predLR))
# Out:
# 0.7681625608033893
# [[4864 1535]
#  [1420 4927]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.76      0.77      6399
#            1       0.76      0.78      0.77      6347
#
#     accuracy                           0.77     12746
#    macro avg       0.77      0.77      0.77     12746
# weighted avg       0.77      0.77      0.77     12746

# %%
score=cross_val_score(LR,x,y)
print(score)
print(score.mean())
print("Difference betn accuracy score and CVC is: ", accuracy_score(y_test,predLR)-score.mean())
# Out:
# [0.75379546 0.76097446 0.76944804 0.76238672 0.7645951 ]
# 0.7622399575168548
# Difference betn accuracy score and CVC is:  0.005922603286534489

# %% [markdown]
# # b) Gradient Boosting Classifier

# %%
#Setting best random_state for Train Test Split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=11)

# %%
gbc = GradientBoostingClassifier()
gbc.fit(x_train,y_train)
predgbc = gbc.predict(x_test)
print(accuracy_score(y_test,predgbc))
print(confusion_matrix(y_test,predgbc))
print(classification_report(y_test,predgbc))
# Out:
# 0.8729013023693708
# [[5329  980]
#  [ 640 5797]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.84      0.87      6309
#            1       0.86      0.90      0.88      6437
#
#     accuracy                           0.87     12746
#    macro avg       0.87      0.87      0.87     12746
# weighted avg       0.87      0.87      0.87     12746

# %%
score=cross_val_score(gbc,x,y)
print(score)
print(score.mean())
print("Difference betn accuracy score and CVC is: ", accuracy_score(y_test,predgbc)-score.mean())
# Out:
# [0.81205131 0.85077086 0.87866306 0.88372367 0.87770716]
# 0.8605832107133414
# Difference betn accuracy score and CVC is:  0.012318091656029373

# %% [markdown]
# # c) Random Forest Classifier

# %%
#Setting best random_state for Train Test Split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=61)

# %%
RFC = RandomForestClassifier()
RFC.fit(x_train,y_train)
predRFC = RFC.predict(x_test)
print(accuracy_score(y_test,predRFC))
print(confusion_matrix(y_test,predRFC))
print(classification_report(y_test,predRFC))
# Out:
# 0.9011454573983995
# [[5635  686]
#  [ 574 5851]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90      6321
#            1       0.90      0.91      0.90      6425
#
#     accuracy                           0.90     12746
#    macro avg       0.90      0.90      0.90     12746
# weighted avg       0.90      0.90      0.90     12746

# %%
score=cross_val_score(RFC,x,y)
print(score)
print(score.mean())
print("Difference betn accuracy score and CVC is: ", accuracy_score(y_test,predRFC)-score.mean())
# Out:
# [0.82652701 0.8823114  0.92609156 0.93256443 0.92855461]
# 0.8992098047455324
# Difference betn accuracy score and CVC is:  0.0019356526528671036

# %% [markdown]
# # d) KNeighborsClassifier

# %%
#Setting best random_state for Train Test Split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=90)

# %%
knn = KNeighborsClassifier() 
knn.fit(x_train, y_train)
pred_knn = knn.predict(x_test)
print("Accuracy:", accuracy_score(y_test, pred_knn))
print("Confusion Matrix:\n", confusion_matrix(y_test, pred_knn))
print("Classification Report:\n", classification_report(y_test, pred_knn))
# Out:
# Accuracy: 0.8615251843715676
# Confusion Matrix:
#  [[5000 1314]
#  [ 451 5981]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.79      0.85      6314
#            1       0.82      0.93      0.87      6432
#
#     accuracy                           0.86     12746
#    macro avg       0.87      0.86      0.86     12746
# weighted avg       0.87      0.86      0.86     12746

# %%
score=cross_val_score(knn,x,y)
print(score)
print(score.mean())
print("Difference betn accuracy score and CVC is: ", accuracy_score(y_test,pred_knn)-score.mean())
# Out:
# [0.84676945 0.84335648 0.87160174 0.8710133  0.87099812]
# 0.8607478168322175
# Difference betn accuracy score and CVC is:  0.0007773675393500934

# %% [markdown]
# # e)Extra Tree Classifier

# %%
#Setting best random_state for Train Test Split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=83)

# %%
etc = ExtraTreesClassifier()
etc.fit(x_train,y_train)
predetc = etc.predict(x_test)
print(accuracy_score(y_test,predetc))
print(confusion_matrix(y_test,predetc))
print(classification_report(y_test,predetc))
# Out:
# 0.9090695120037658
# [[5665  731]
#  [ 428 5922]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91      6396
#            1       0.89      0.93      0.91      6350
#
#     accuracy                           0.91     12746
#    macro avg       0.91      0.91      0.91     12746
# weighted avg       0.91      0.91      0.91     12746

# %%
score=cross_val_score(etc,x,y)
print(score)
print(score.mean())
print("Difference betn accuracy score and CVC is: ", accuracy_score(y_test,predetc)-score.mean())
# Out:
# [0.86253972 0.89278569 0.92915147 0.92997529 0.92902542]
# 0.9086955166629099
# Difference betn accuracy score and CVC is:  0.0003739953408559149

# %% [markdown]
# # f) Bagging Classifier

# %%
#Setting best random_state for Train Test Split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=36)

# %%
bc = BaggingClassifier()
bc.fit(x_train,y_train)
predbc = bc.predict(x_test)
print(accuracy_score(y_test,predbc))
print(confusion_matrix(y_test,predbc))
print(classification_report(y_test,predbc))
# Out:
# 0.8820021967676134
# [[5657  698]
#  [ 806 5585]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.89      0.88      6355
#            1       0.89      0.87      0.88      6391
#
#     accuracy                           0.88     12746
#    macro avg       0.88      0.88      0.88     12746
# weighted avg       0.88      0.88      0.88     12746

# %%
score=cross_val_score(bc,x,y)
print(score)
print(score.mean())
print("Difference betn accuracy score and CVC is: ", accuracy_score(y_test,predbc)-score.mean())
# Out:
# [0.7905143  0.86289279 0.9164411  0.91726492 0.91572505]
# 0.8805676291643423
# Difference betn accuracy score and CVC is:  0.0014345676032710974

# %% [markdown]
# # g) AdaBoost Classifier

# %%
#Setting best random_state for Train Test Split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=83)

# %%
abc = AdaBoostClassifier()
abc.fit(x_train,y_train)
predabc = abc.predict(x_test)
print(accuracy_score(y_test,predabc))
print(confusion_matrix(y_test,predabc))
print(classification_report(y_test,predabc))
# Out:
# 0.8592499607720069
# [[5302 1094]
#  [ 700 5650]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.83      0.86      6396
#            1       0.84      0.89      0.86      6350
#
#     accuracy                           0.86     12746
#    macro avg       0.86      0.86      0.86     12746
# weighted avg       0.86      0.86      0.86     12746

# %%
score=cross_val_score(abc,x,y)
print(score)
print(score.mean())
print("Difference betn accuracy score and CVC is: ", accuracy_score(y_test,predabc)-score.mean())
# Out:
# [0.80640226 0.84347417 0.86512887 0.8699541  0.86593691]
# 0.8501792617844295
# Difference betn accuracy score and CVC is:  0.009070698987577397

# %% [markdown]
# Observation: Considering the difference between accuracy score and CVC as .0003 and accuracy 90.90% the best model is Extra Tree Classifier

# %% [markdown]
# # Hypertunning

# %%
from sklearn.model_selection import GridSearchCV
parameters = {"criterion" : ['gini','entropy'],
             "random_state" : [10,50,100],
             "max_depth" : [None,10,20],
             "n_jobs" : [-2,-1,1],
             "n_estimators" : [50,100,200]}

# %%
#GCV = GridSearchCV(ExtraTreesClassifier(),parameters,cv=5)

# %%
#GCV.fit(x_train,y_train)

# %%
#GCV.best_params_

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=83)

# %%
income_model = ExtraTreesClassifier()
income_model.fit(x_train,y_train)
pred = income_model.predict(x_test)
acc = accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 90.60097285422877

# %% [markdown]
# # Ploting Receiver Operating Characteristic (ROC) Curve and AUC

# %%
from sklearn import metrics
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# %%
y_pred_prob = income_model.predict_proba(x_test)[:,1]
fpr, tpr, threshold = metrics.roc_curve(y_test, pred,pos_label=1)
roc_auc = metrics.auc(fpr, tpr)

# %%
# plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # Saving Model

# %%
import joblib
joblib.dump(income_model,'income_prediction.pki')
# Out:
# ['income_prediction.pki']

# %%
model = joblib.load('income_prediction.pki')
prediction = model.predict(x_test)
prediction
# Out:
# array([0, 1, 1, ..., 1, 0, 1])

# %%
a = np.array(y_test)
df_income=pd.DataFrame()
df_income['Predicted'] = prediction
df_income['Original'] = a

# %%
df_income
# Out:
#        Predicted  Original
# 0              0         0
# 1              1         1
# 2              1         1
# 3              0         0
# 4              0         0
# ...          ...       ...
# 12741          0         0
# 12742          0         0
# 12743          1         1
# 12744          0         0
# 12745          1         1
#
# [12746 rows x 2 columns]
